# %%
import pandas as pd

# %%
# Out:
#           Column1   Column2        Column3 Column4  Column5 Column6 Column7  \
# 0  bp (Diastolic)  bp limit             sg      al      NaN     rbc      su
# 1               0         0  1.019 - 1.021   1 - 1      NaN       0     < 0
# 2               0         0  1.009 - 1.011     < 0      NaN       0     < 0
# 3               0         0  1.009 - 1.011     ? 4      NaN       1     < 0
# 4               1         1  1.009 - 1.011   3 - 3      NaN       0     < 0
#
#   Column8 Column9 Column10  ... Column21 Column22 Column23 Column24 Column25  \
# 0      pc     pcc       ba  ...       dm      cad    appet       pe      ane
# 1       0       0        0  ...        0        0        0        0        0
# 2       0       0        0  ...        0        0        0        0        0
# 3       1       0        1  ...        0        0        1        0        0
# 4       0       0        0  ...        0        0        0        0        0
#
# ...
